# %%
import pandas as pd
import numpy as np
from scipy.stats import zscore
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_excel(r'C:\Users\Anderson\Desktop\we_fn_use_c_marketing_customer_value_analysis.xlsx')
df
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington             2.763519e+09       No     Basic
# 1     QZ44356     Arizona             6.979536e+09       No  Extended
# 2     AI49188      Nevada             1.288743e+09       No   Premium
# 3     WW63253  California             7.645862e+09       No     Basic
# 4     HB64268  Washington             2.813693e+09       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             2.340599e+09       No     Basic
# 9130  PK87824  California             3.096511e+09      Yes  Extended
# 9131  TD14365  California             8.163890e+09       No  Extended
# 9132  UP19263  California             7.524442e+09       No  Extended
# 9133  Y167826  California             2.611837e+09       No  Extended
#
#      Education    Effective To Date EmploymentStatus Gender  Income  ...  \
# 0     Bachelor              2/24/11         Employed      F   56274  ...
# 1     Bachelor              1/31/11       Unemployed      F       0  ...
# 2     Bachelor              2/19/11         Employed      F   48767  ...
# 3     Bachelor              1/20/11       Unemployed      M       0  ...
# 4     Bachelor  2011-03-02 00:00:00         Employed      M   43836  ...
# ...        ...                  ...              ...    ...     ...  ...
# 9129  Bachelor  2011-10-02 00:00:00         Employed      M   71941  ...
# 9130   College  2011-12-02 00:00:00         Employed      F   21604  ...
# 9131  Bachelor  2011-06-02 00:00:00       Unemployed      M       0  ...
# 9132   College  2011-03-02 00:00:00         Employed      M   21941  ...
# 9133   College              2/14/11       Unemployed      M       0  ...
#
#      Months Since Policy Inception Number of Open Complaints  \
# 0                                5                         0
# 1                               42                         0
# 2                               38                         0
# 3                               65                         0
# 4                               44                         0
# ...                            ...                       ...
# 9129                            89                         0
# 9130                            28                         0
# 9131                            37                         3
# 9132                             3                         0
# 9133                            90                         0
#
#       Number of Policies     Policy Type        Policy  Renew Offer Type  \
# 0                      1  Corporate Auto  Corporate L3            Offer1
# 1                      8   Personal Auto   Personal L3            Offer3
# 2                      2   Personal Auto   Personal L3            Offer1
# 3                      7  Corporate Auto  Corporate L2            Offer1
# 4                      1   Personal Auto   Personal L1            Offer1
# ...                  ...             ...           ...               ...
# 9129                   2   Personal Auto   Personal L1            Offer2
# 9130                   1  Corporate Auto  Corporate L3            Offer1
# 9131                   2  Corporate Auto  Corporate L2            Offer1
# 9132                   3   Personal Auto   Personal L2            Offer3
# 9133                   1  Corporate Auto  Corporate L3            Offer4
#
#       Sales Channel Total Claim Amount  Vehicle Class Vehicle Size
# 0             Agent       3.848111e+08   Two-Door Car      Medsize
# 1             Agent       1.131465e+09  Four-Door Car      Medsize
# 2             Agent       5.664722e+08   Two-Door Car      Medsize
# 3       Call Center       5.298813e+08            SUV      Medsize
# 4             Agent       1.381309e+08  Four-Door Car      Medsize
# ...             ...                ...            ...          ...
# 9129            Web       1.982348e+08  Four-Door Car      Medsize
# 9130         Branch       3.792000e+02  Four-Door Car      Medsize
# 9131         Branch       7.907850e+08  Four-Door Car      Medsize
# 9132         Branch       6.912000e+02  Four-Door Car        Large
# 9133    Call Center       3.696000e+02   Two-Door Car      Medsize
#
# [9134 rows x 24 columns]

# %%
print(df.isnull().sum())
# Out:
# Customer                         0
# State                            0
# Customer Lifetime Value          0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Renew Offer Type                 0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %%
#We will start with removing outliers. So far, we have discussed different methods to remove outliers. 
#Use the one you feel more comfortable with, define a function for that. 
#Use the function to remove the outliers and apply it to the dataframe.

# %%
def remove_outliers(df, threshold=3):
    z_scores = np.abs(zscore(df.select_dtypes(include=[np.number])))
    
    df_clean = df[(z_scores < threshold).all(axis=1)]
    
    return df_clean

data_clean = remove_outliers(df)

# %%
#Create a copy of the dataframe for the data wrangling.

# %%
data_wrangle = data_clean.copy()

# %%
#Normalize the continuous variables. You can use any one method you want.

# %%
continuous_cols = data_wrangle.select_dtypes(include=[np.number]).columns
scaler = MinMaxScaler()
data_wrangle[continuous_cols] = scaler.fit_transform(data_wrangle[continuous_cols])

# %%
#4.Encode the categorical variables

# %%
data_wrangle['Coverage'] = data_wrangle['Coverage'].map({"Basic": 0, "Extended": 1, "Premium": 2})
data_wrangle['EmploymentStatus'] = data_wrangle['EmploymentStatus'].map({"Unemployed": 0, "Employed": 1, "Retired": 2})
data_wrangle['Location Code'] = data_wrangle['Location Code'].map({"Rural": 0, "Suburban": 1, "Urban": 2})
data_wrangle['Vehicle Size'] = data_wrangle['Vehicle Size'].map({"Small": 0, "Medsize": 1, "Large": 2})

data_wrangle = pd.get_dummies(data_wrangle, columns=[
    'State', 'Marital Status', 'Policy Type', 'Policy', 
    'Renew Offer Type', 'Customer', 'Sales Channel', 'Vehicle Class'
])

# %%
#5.The time variable can be useful. Try to transform its data into a useful one. Hint: Day week and month as integers might be useful.

# %%
data_wrangle['Effective To Date'] = pd.to_datetime(data_wrangle['Effective To Date'])
# Out:
# C:\Users\Anderson\AppData\Local\Temp\ipykernel_6612\2511329864.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data_wrangle['Effective To Date'] = pd.to_datetime(data_wrangle['Effective To Date'])

# %%
data_wrangle['day'] = data_wrangle['Effective To Date'].dt.day
data_wrangle['week'] = data_wrangle['Effective To Date'].dt.isocalendar().week
data_wrangle['month'] = data_wrangle['Effective To Date'].dt.month


# Drop the original 'time' column if not needed
data_wrangle.drop('Effective To Date', axis=1, inplace=True)

# %%
#6.Since the model will only accept numerical data, check and make sure that every column is numerical, if some are not, change it using encoding.

# %%
for column in data_wrangle.columns:
    print(f"{column}: {data_wrangle[column].dtype}")
# Out:
# Customer Lifetime Value: float64
# Response: object
# Coverage: float64
# Education: object
# EmploymentStatus: float64
# Gender: object
# Income: float64
# Location Code: float64
# Monthly Premium Auto: float64
# Months Since Last Claim: float64
# Months Since Policy Inception: float64
# Number of Open Complaints: float64
# Number of Policies: float64
# Total Claim Amount: float64
# Vehicle Size: float64
# State_Arizona: bool
# State_California: bool
# State_Nevada: bool
# State_Oregon: bool
# State_Washington: bool
# Marital Status_Divorced: bool
# Marital Status_Married: bool
# Marital Status_Single: bool
# Policy Type_Corporate Auto: bool
# Policy Type_Personal Auto: bool
# Policy Type_Special Auto: bool
# Policy_Corporate L1: bool
# Policy_Corporate L2: bool
# Policy_Corporate L3: bool
# Policy_Personal L1: bool
# Policy_Personal L2: bool
# Policy_Personal L3: bool
# Policy_Special L1: bool
# Policy_Special L2: bool
# Policy_Special L3: bool
# Renew Offer Type_Offer1: bool
# Renew Offer Type_Offer2: bool
# Renew Offer Type_Offer3: bool
# Renew Offer Type_Offer4: bool
# Customer_AA11235: bool
# Customer_AA16582: bool
# Customer_AA30683: bool
# Customer_AA35519: bool
# Customer_AA56476: bool
# Customer_AA69265: bool
# Customer_AA71604: bool
# Customer_AA93585: bool
# Customer_AB13432: bool
# Customer_AB21519: bool
# Customer_AB23825: bool
# Customer_AB26022: bool
# Customer_AB31813: bool
# Customer_AB45325: bool
# Customer_AB60627: bool
# Customer_AB62982: bool
# Customer_AB69140: bool
# Customer_AB72731: bool
# Customer_AB73565: bool
# Customer_AB78984: bool
# Customer_AB96670: bool
# Customer_AB98823: bool
# Customer_AC13887: bool
# Customer_AC22873: bool
# Customer_AC24378: bool
# Customer_AC40767: bool
# Customer_AC42963: bool
# Customer_AC58002: bool
# Customer_AC67315: bool
# Customer_AC73173: bool
# Customer_AC75391: bool
# Customer_AC79024: bool
# Customer_AD18174: bool
# Customer_AD28349: bool
# Customer_AD28535: bool
# Customer_AD33653: bool
# Customer_AD33971: bool
# Customer_AD38685: bool
# Customer_AD56037: bool
# Customer_AD63766: bool
# Customer_AD71478: bool
# Customer_AD89594: bool
# Customer_AE23906: bool
# Customer_AE30506: bool
# Customer_AE60813: bool
# Customer_AE62631: bool
# Customer_AE74442: bool
# Customer_AE89300: bool
# Customer_AE90216: bool
# Customer_AE93522: bool
# Customer_AE98193: bool
# Customer_AF10970: bool
# Customer_AF17671: bool
# Customer_AF20716: bool
# Customer_AF36894: bool
# Customer_AF37776: bool
# Customer_AF41118: bool
# Customer_AF47139: bool
# Customer_AF48816: bool
# Customer_AF49027: bool
# Customer_AF49625: bool
# Customer_AF69537: bool
# Customer_AF81450: bool
# Customer_AG22225: bool
# Customer_AG32304: bool
# Customer_AG39150: bool
# Customer_AG45299: bool
# Customer_AG47947: bool
# Customer_AG56998: bool
# Customer_AG58599: bool
# Customer_AG62087: bool
# Customer_AG62140: bool
# Customer_AG85127: bool
# Customer_AG85615: bool
# Customer_AH17051: bool
# Customer_AH22694: bool
# Customer_AH39293: bool
# Customer_AH41065: bool
# Customer_AH41449: bool
# Customer_AH53588: bool
# Customer_AH55475: bool
# Customer_AH58807: bool
# Customer_AH65907: bool
# Customer_AH89786: bool
# Customer_AH92481: bool
# Customer_AH97088: bool
# Customer_AH99727: bool
# Customer_AI11191: bool
# Customer_AI14767: bool
# Customer_AI16519: bool
# Customer_AI47152: bool
# Customer_AI49188: bool
# Customer_AI49712: bool
# Customer_AI58313: bool
# Customer_AI58500: bool
# Customer_AI61368: bool
# Customer_AI74959: bool
# Customer_AI85843: bool
# Customer_AJ32539: bool
# Customer_AJ58038: bool
# Customer_AJ69060: bool
# Customer_AJ69778: bool
# Customer_AJ89107: bool
# Customer_AK11669: bool
# Customer_AK11719: bool
# Customer_AK17025: bool
# Customer_AK44985: bool
# Customer_AK54675: bool
# Customer_AK59340: bool
# Customer_AK61491: bool
# Customer_AK72422: bool
# Customer_AK90865: bool
# Customer_AL21967: bool
# Customer_AL27471: bool
# Customer_AL35726: bool
# Customer_AL43715: bool
# Customer_AL46984: bool
# Customer_AL50693: bool
# Customer_AL78075: bool
# Customer_AL95338: bool
# Customer_AL96740: bool
# Customer_AM17304: bool
# Customer_AM26598: bool
# Customer_AM28777: bool
# Customer_AM29546: bool
# Customer_AM30008: bool
# Customer_AM32820: bool
# Customer_AM34581: bool
# Customer_AM36670: bool
# Customer_AM53473: bool
# Customer_AM57175: bool
# Customer_AM72411: bool
# Customer_AM88377: bool
# Customer_AM89558: bool
# Customer_AM92343: bool
# Customer_AM94127: bool
# Customer_AM99192: bool
# Customer_AN21193: bool
# Customer_AN32867: bool
# Customer_AN36757: bool
# Customer_AN47199: bool
# Customer_AN53225: bool
# Customer_AN57220: bool
# Customer_AN67558: bool
# Customer_AN79079: bool
# Customer_AN80983: bool
# Customer_AN97123: bool
# Customer_AO20938: bool
# Customer_AO40386: bool
# Customer_AO42003: bool
# Customer_AO46433: bool
# Customer_AO74776: bool
# Customer_AO77635: bool
# Customer_AO87348: bool
# Customer_AO98601: bool
# Customer_AP23850: bool
# Customer_AP27994: bool
# Customer_AP32891: bool
# Customer_AP34711: bool
# Customer_AP46166: bool
# Customer_AP47670: bool
# Customer_AP52126: bool
# Customer_AP52565: bool
# Customer_AP56340: bool
# Customer_AP59947: bool
# Customer_AP63665: bool
# Customer_AP65984: bool
# Customer_AP67935: bool
# Customer_AP89323: bool
# Customer_AP90638: bool
# Customer_AP95078: bool
# Customer_AP98768: bool
# Customer_AQ11656: bool
# Customer_AQ25590: bool
# Customer_AQ30231: bool
# Customer_AQ34238: bool
# Customer_AQ46199: bool
# Customer_AQ51159: bool
# Customer_AQ51368: bool
# Customer_AQ52711: bool
# Customer_AQ70385: bool
# Customer_AQ70619: bool
# Customer_AQ91207: bool
# Customer_AQ94108: bool
# Customer_AR17553: bool
# Customer_AR25213: bool
# Customer_AR47849: bool
# Customer_AR59416: bool
# Customer_AR61426: bool
# Customer_AR63478: bool
# Customer_AR69517: bool
# Customer_AR75105: bool
# Customer_AR83514: bool
# Customer_AR96516: bool
# Customer_AR99766: bool
# Customer_AS17174: bool
# Customer_AS18084: bool
# Customer_AS26192: bool
# Customer_AS48176: bool
# Customer_AS55478: bool
# Customer_AS55677: bool
# Customer_AS60178: bool
# Customer_AS62048: bool
# Customer_AS77287: bool
# Customer_AS78838: bool
# Customer_AS93181: bool
# Customer_AS97690: bool
# Customer_AS99827: bool
# Customer_AT13963: bool
# Customer_AT18041: bool
# Customer_AT24793: bool
# Customer_AT29024: bool
# Customer_AT30076: bool
# Customer_AT31367: bool
# Customer_AT33529: bool
# Customer_AT41276: bool
# Customer_AT49447: bool
# Customer_AT55072: bool
# Customer_AT62618: bool
# Customer_AT72574: bool
# Customer_AT79008: bool
# Customer_AT84725: bool
# Customer_AT86990: bool
# Customer_AT93647: bool
# Customer_AT98182: bool
# Customer_AU11344: bool
# Customer_AU13233: bool
# Customer_AU23837: bool
# Customer_AU45793: bool
# Customer_AU46604: bool
# Customer_AU62013: bool
# Customer_AU71562: bool
# Customer_AU75025: bool
# Customer_AU77281: bool
# Customer_AU91447: bool
# Customer_AU94279: bool
# Customer_AU96286: bool
# Customer_AU98438: bool
# Customer_AV17528: bool
# Customer_AV25133: bool
# Customer_AV49798: bool
# Customer_AV72430: bool
# Customer_AV76907: bool
# Customer_AV93209: bool
# Customer_AW17574: bool
# Customer_AW18068: bool
# Customer_AW27717: bool
# Customer_AW36627: bool
# Customer_AW48347: bool
# Customer_AW71157: bool
# Customer_AW73065: bool
# Customer_AW77988: bool
# Customer_AW84946: bool
# Customer_AX10148: bool
# Customer_AX28231: bool
# Customer_AX36597: bool
# Customer_AX38728: bool
# Customer_AX39008: bool
# Customer_AX45422: bool
# Customer_AX56708: bool
# Customer_AX70794: bool
# Customer_AX71238: bool
# Customer_AX71707: bool
# Customer_AX86150: bool
# Customer_AX86552: bool
# Customer_AX99820: bool
# Customer_AY18433: bool
# Customer_AY19539: bool
# Customer_AY26056: bool
# Customer_AY29281: bool
# Customer_AY30324: bool
# Customer_AY35050: bool
# Customer_AY35539: bool
# Customer_AY43037: bool
# Customer_AY52869: bool
# Customer_AY55759: bool
# Customer_AY59197: bool
# Customer_AY73718: bool
# Customer_AY84441: bool
# Customer_AY88788: bool
# Customer_AY98473: bool
# Customer_AY99324: bool
# Customer_AZ15952: bool
# Customer_AZ29426: bool
# Customer_AZ31562: bool
# Customer_AZ34845: bool
# Customer_AZ36763: bool
# Customer_AZ38648: bool
# Customer_AZ43057: bool
# Customer_AZ50087: bool
# Customer_AZ64856: bool
# Customer_AZ68072: bool
# Customer_AZ68184: bool
# Customer_AZ74055: bool
# Customer_AZ75509: bool
# Customer_AZ77669: bool
# Customer_AZ82578: bool
# Customer_AZ87715: bool
# Customer_AZ95587: bool
# Customer_BA17836: bool
# Customer_BA19651: bool
# Customer_BA26944: bool
# Customer_BA38428: bool
# Customer_BA40043: bool
# Customer_BA49679: bool
# Customer_BA51898: bool
# Customer_BA52133: bool
# Customer_BA56812: bool
# Customer_BA66627: bool
# Customer_BA75404: bool
# Customer_BA87048: bool
# Customer_BA87216: bool
# Customer_BA92673: bool
# Customer_BA97018: bool
# Customer_BB10681: bool
# Customer_BB11622: bool
# Customer_BB19609: bool
# Customer_BB21794: bool
# Customer_BB41401: bool
# Customer_BB48165: bool
# Customer_BB65725: bool
# Customer_BB82067: bool
# Customer_BC31913: bool
# Customer_BC34309: bool
# Customer_BC35753: bool
# Customer_BC43958: bool
# Customer_BC47264: bool
# Customer_BC48076: bool
# Customer_BC51708: bool
# Customer_BC52397: bool
# Customer_BC53363: bool
# Customer_BC53546: bool
# Customer_BC62782: bool
# Customer_BC64697: bool
# Customer_BC66536: bool
# Customer_BC66921: bool
# Customer_BC77846: bool
# Customer_BC85847: bool
# Customer_BC86800: bool
# Customer_BC87161: bool
# Customer_BC87551: bool
# Customer_BC90645: bool
# Customer_BC97773: bool
# Customer_BD12981: bool
# Customer_BD13927: bool
# Customer_BD16530: bool
# Customer_BD35524: bool
# Customer_BD35676: bool
# Customer_BD36887: bool
# Customer_BD42101: bool
# Customer_BD53342: bool
# Customer_BD58297: bool
# Customer_BD66455: bool
# Customer_BD69478: bool
# Customer_BD70337: bool
# Customer_BD77090: bool
# Customer_BD84823: bool
# Customer_BD89564: bool
# Customer_BE10809: bool
# Customer_BE17305: bool
# Customer_BE25221: bool
# Customer_BE31382: bool
# Customer_BE33446: bool
# Customer_BE54454: bool
# Customer_BE55425: bool
# Customer_BE61743: bool
# Customer_BE62503: bool
# Customer_BE65350: bool
# Customer_BE69929: bool
# Customer_BE75190: bool
# Customer_BE78308: bool
# Customer_BE92692: bool
# Customer_BF45697: bool
# Customer_BF54215: bool
# Customer_BF56053: bool
# Customer_BF69918: bool
# Customer_BF72793: bool
# Customer_BG15419: bool
# Customer_BG19572: bool
# Customer_BG30513: bool
# Customer_BG42047: bool
# Customer_BG44829: bool
# Customer_BG48083: bool
# Customer_BG51419: bool
# Customer_BG55927: bool
# Customer_BG60187: bool
# Customer_BG73480: bool
# Customer_BG74433: bool
# Customer_BG76355: bool
# Customer_BG80246: bool
# Customer_BG84194: bool
# Customer_BG85305: bool
# Customer_BG95711: bool
# Customer_BG96711: bool
# Customer_BH11344: bool
# Customer_BH23017: bool
# Customer_BH28530: bool
# Customer_BH35016: bool
# Customer_BH35482: bool
# Customer_BH36570: bool
# Customer_BH36973: bool
# Customer_BH43020: bool
# Customer_BH43379: bool
# Customer_BH52611: bool
# Customer_BH60627: bool
# Customer_BH61054: bool
# Customer_BH68769: bool
# Customer_BH86846: bool
# Customer_BI17208: bool
# Customer_BI27443: bool
# Customer_BI34286: bool
# Customer_BI34376: bool
# Customer_BI38192: bool
# Customer_BI46495: bool
# Customer_BI76326: bool
# Customer_BI81476: bool
# Customer_BJ13380: bool
# Customer_BJ18904: bool
# Customer_BJ22117: bool
# Customer_BJ26599: bool
# Customer_BJ53923: bool
# Customer_BJ58596: bool
# Customer_BJ65040: bool
# Customer_BJ82316: bool
# Customer_BK15048: bool
# Customer_BK21146: bool
# Customer_BK43823: bool
# Customer_BK47926: bool
# Customer_BK57087: bool
# Customer_BK59444: bool
# Customer_BK61065: bool
# Customer_BK73302: bool
# Customer_BK76107: bool
# Customer_BK83393: bool
# Customer_BK85520: bool
# Customer_BL12371: bool
# Customer_BL13393: bool
# Customer_BL29046: bool
# Customer_BL29240: bool
# Customer_BL42392: bool
# Customer_BL44708: bool
# Customer_BL44722: bool
# Customer_BL54814: bool
# Customer_BL55947: bool
# Customer_BL66157: bool
# Customer_BL79888: bool
# Customer_BL89983: bool
# Customer_BL90769: bool
# Customer_BL93527: bool
# Customer_BL93659: bool
# Customer_BM15160: bool
# Customer_BM16805: bool
# Customer_BM21532: bool
# Customer_BM27144: bool
# Customer_BM30720: bool
# Customer_BM31989: bool
# Customer_BM39234: bool
# Customer_BM46418: bool
# Customer_BM53580: bool
# Customer_BM55732: bool
# Customer_BM66931: bool
# Customer_BM69081: bool
# Customer_BM69818: bool
# Customer_BM71358: bool
# Customer_BM83544: bool
# Customer_BM92346: bool
# Customer_BN14307: bool
# Customer_BN38134: bool
# Customer_BN45584: bool
# Customer_BN46866: bool
# Customer_BN62219: bool
# Customer_BN74259: bool
# Customer_BN74268: bool
# Customer_BN77676: bool
# Customer_BN80677: bool
# Customer_BN83547: bool
# Customer_BN87372: bool
# Customer_BN89470: bool
# Customer_BN90616: bool
# Customer_BN91755: bool
# Customer_BO15959: bool
# Customer_BO21461: bool
# Customer_BO42776: bool
# Customer_BO46265: bool
# Customer_BO58202: bool
# Customer_BO81145: bool
# Customer_BO87401: bool
# Customer_BO92934: bool
# Customer_BO94261: bool
# Customer_BP25150: bool
# Customer_BP34620: bool
# Customer_BP35803: bool
# Customer_BP49831: bool
# Customer_BP53979: bool
# Customer_BP54465: bool
# Customer_BP69529: bool
# Customer_BP74289: bool
# Customer_BP83941: bool
# Customer_BP90016: bool
# Customer_BP92643: bool
# Customer_BQ12347: bool
# Customer_BQ15946: bool
# Customer_BQ20851: bool
# Customer_BQ28323: bool
# Customer_BQ32117: bool
# Customer_BQ41371: bool
# Customer_BQ51587: bool
# Customer_BQ51616: bool
# Customer_BQ60673: bool
# Customer_BQ88033: bool
# Customer_BQ94892: bool
# Customer_BQ94931: bool
# Customer_BQ99053: bool
# Customer_BR13613: bool
# Customer_BR22486: bool
# Customer_BR23201: bool
# Customer_BR24590: bool
# Customer_BR28896: bool
# Customer_BR39076: bool
# Customer_BR40272: bool
# Customer_BR44176: bool
# Customer_BR50492: bool
# Customer_BR69566: bool
# Customer_BR76202: bool
# Customer_BR77413: bool
# Customer_BR99015: bool
# Customer_BS13062: bool
# Customer_BS13111: bool
# Customer_BS26376: bool
# Customer_BS29584: bool
# Customer_BS34332: bool
# Customer_BS53322: bool
# Customer_BS77946: bool
# Customer_BS83666: bool
# Customer_BS87947: bool
# Customer_BS90503: bool
# Customer_BS91566: bool
# Customer_BS94221: bool
# Customer_BS95225: bool
# Customer_BS96517: bool
# Customer_BT20606: bool
# Customer_BT30554: bool
# Customer_BT49333: bool
# Customer_BT57285: bool
# Customer_BT61680: bool
# Customer_BT68954: bool
# Customer_BT76268: bool
# Customer_BT78461: bool
# Customer_BT78503: bool
# Customer_BU14748: bool
# Customer_BU15334: bool
# Customer_BU16704: bool
# Customer_BU17847: bool
# Customer_BU27331: bool
# Customer_BU41599: bool
# Customer_BU44523: bool
# Customer_BU53191: bool
# Customer_BU59722: bool
# Customer_BU61331: bool
# Customer_BU70181: bool
# Customer_BU71528: bool
# Customer_BU72276: bool
# Customer_BU72633: bool
# Customer_BU79786: bool
# Customer_BU81591: bool
# Customer_BV12771: bool
# Customer_BV16459: bool
# Customer_BV22194: bool
# Customer_BV25135: bool
# Customer_BV27017: bool
# Customer_BV33510: bool
# Customer_BV35683: bool
# Customer_BV36386: bool
# Customer_BV53716: bool
# Customer_BV55014: bool
# Customer_BV57364: bool
# Customer_BV63942: bool
# Customer_BV69462: bool
# Customer_BV79904: bool
# Customer_BV80674: bool
# Customer_BV86143: bool
# Customer_BV91898: bool
# Customer_BV98316: bool
# Customer_BW25236: bool
# Customer_BW43011: bool
# Customer_BW46202: bool
# Customer_BW51534: bool
# Customer_BW52697: bool
# Customer_BW63560: bool
# Customer_BW65176: bool
# Customer_BW76745: bool
# Customer_BW79345: bool
# Customer_BW80872: bool
# Customer_BW88060: bool
# Customer_BW94308: bool
# Customer_BX20227: bool
# Customer_BX20846: bool
# Customer_BX24569: bool
# Customer_BX35013: bool
# Customer_BX45636: bool
# Customer_BX51438: bool
# Customer_BX70848: bool
# Customer_BX88206: bool
# Customer_BX88330: bool
# Customer_BX94438: bool
# Customer_BY23642: bool
# Customer_BY54111: bool
# Customer_BY59578: bool
# Customer_BY62906: bool
# Customer_BY75330: bool
# Customer_BY78730: bool
# Customer_BY84257: bool
# Customer_BY88565: bool
# Customer_BY88757: bool
# Customer_BZ12077: bool
# Customer_BZ33435: bool
# Customer_BZ36030: bool
# Customer_BZ44726: bool
# Customer_BZ47770: bool
# Customer_BZ50261: bool
# Customer_BZ71120: bool
# Customer_BZ81849: bool
# Customer_BZ85280: bool
# Customer_BZ92811: bool
# Customer_CA14631: bool
# Customer_CA22248: bool
# Customer_CA29908: bool
# Customer_CA45756: bool
# Customer_CA47176: bool
# Customer_CA52541: bool
# Customer_CA54112: bool
# Customer_CA55066: bool
# Customer_CA56041: bool
# Customer_CA58346: bool
# Customer_CA62597: bool
# Customer_CA70404: bool
# Customer_CA79988: bool
# Customer_CA86085: bool
# Customer_CA96568: bool
# Customer_CB15842: bool
# Customer_CB17191: bool
# Customer_CB44654: bool
# Customer_CB52667: bool
# Customer_CB58476: bool
# Customer_CB59349: bool
# Customer_CB61335: bool
# Customer_CB64729: bool
# Customer_CB77819: bool
# Customer_CB95310: bool
# Customer_CB96381: bool
# Customer_CC15295: bool
# Customer_CC16034: bool
# Customer_CC30924: bool
# Customer_CC31456: bool
# Customer_CC43119: bool
# Customer_CC46747: bool
# Customer_CC85895: bool
# Customer_CC88237: bool
# Customer_CC91503: bool
# Customer_CC92362: bool
# Customer_CC93587: bool
# Customer_CC94413: bool
# Customer_CD14267: bool
# Customer_CD27895: bool
# Customer_CD38665: bool
# Customer_CD45044: bool
# Customer_CD48033: bool
# Customer_CD55111: bool
# Customer_CD56261: bool
# Customer_CD68182: bool
# Customer_CD71502: bool
# Customer_CD71877: bool
# Customer_CD76093: bool
# Customer_CD86811: bool
# Customer_CD88896: bool
# Customer_CD95333: bool
# Customer_CE10235: bool
# Customer_CE11308: bool
# Customer_CE11667: bool
# Customer_CE12380: bool
# Customer_CE16324: bool
# Customer_CE17166: bool
# Customer_CE17855: bool
# Customer_CE21829: bool
# Customer_CE41738: bool
# Customer_CE46475: bool
# Customer_CE56187: bool
# Customer_CE68841: bool
# Customer_CE69971: bool
# Customer_CE71123: bool
# Customer_CE72177: bool
# Customer_CE75354: bool
# Customer_CE92675: bool
# Customer_CE94751: bool
# Customer_CF15086: bool
# Customer_CF15252: bool
# Customer_CF15558: bool
# Customer_CF26052: bool
# Customer_CF26207: bool
# Customer_CF27806: bool
# Customer_CF40646: bool
# Customer_CF41619: bool
# Customer_CF44171: bool
# Customer_CF46699: bool
# Customer_CF57022: bool
# Customer_CF62430: bool
# Customer_CF62992: bool
# Customer_CF73234: bool
# Customer_CF85061: bool
# Customer_CF95802: bool
# Customer_CG13512: bool
# Customer_CG33085: bool
# Customer_CG36206: bool
# Customer_CG39505: bool
# Customer_CG43444: bool
# Customer_CG60089: bool
# Customer_CG69038: bool
# Customer_CG90504: bool
# Customer_CG92708: bool
# Customer_CG94611: bool
# Customer_CH20044: bool
# Customer_CH38655: bool
# Customer_CH50339: bool
# Customer_CH50584: bool
# Customer_CH73843: bool
# Customer_CH76379: bool
# Customer_CH78309: bool
# Customer_CH81088: bool
# Customer_CH85444: bool
# Customer_CH95772: bool
# Customer_CH96412: bool
# Customer_CH97539: bool
# Customer_CH97666: bool
# Customer_CI19819: bool
# Customer_CI24326: bool
# Customer_CI27304: bool
# Customer_CI30899: bool
# Customer_CI38171: bool
# Customer_CI38330: bool
# Customer_CI51999: bool
# Customer_CI57475: bool
# Customer_CI60365: bool
# Customer_CI95726: bool
# Customer_CI99444: bool
# Customer_CJ15590: bool
# Customer_CJ29883: bool
# Customer_CJ31839: bool
# Customer_CJ35075: bool
# Customer_CJ46674: bool
# Customer_CJ51511: bool
# Customer_CJ59481: bool
# Customer_CJ63667: bool
# Customer_CJ64468: bool
# Customer_CJ72056: bool
# Customer_CJ78727: bool
# Customer_CJ78860: bool
# Customer_CJ81391: bool
# Customer_CJ81799: bool
# Customer_CJ97736: bool
# Customer_CK14803: bool
# Customer_CK15380: bool
# Customer_CK19789: bool
# Customer_CK24264: bool
# Customer_CK29372: bool
# Customer_CK31454: bool
# Customer_CK35310: bool
# Customer_CK36026: bool
# Customer_CK39096: bool
# Customer_CK40732: bool
# Customer_CK74127: bool
# Customer_CK85904: bool
# Customer_CL10476: bool
# Customer_CL37990: bool
# Customer_CL38124: bool
# Customer_CL38926: bool
# Customer_CL52383: bool
# Customer_CL70684: bool
# Customer_CL73599: bool
# Customer_CL79250: bool
# Customer_CL97519: bool
# Customer_CM38959: bool
# Customer_CM42637: bool
# Customer_CM48429: bool
# Customer_CM52565: bool
# Customer_CM55703: bool
# Customer_CM59084: bool
# Customer_CM61827: bool
# Customer_CM66204: bool
# Customer_CM73149: bool
# Customer_CM78608: bool
# Customer_CM84035: bool
# Customer_CM88932: bool
# Customer_CM94209: bool
# Customer_CM94425: bool
# Customer_CM95716: bool
# Customer_CN13435: bool
# Customer_CN16311: bool
# Customer_CN17219: bool
# Customer_CN19138: bool
# Customer_CN22369: bool
# Customer_CN23147: bool
# Customer_CN24514: bool
# Customer_CN29830: bool
# Customer_CN30964: bool
# Customer_CN31328: bool
# Customer_CN49086: bool
# Customer_CN53343: bool
# Customer_CN63432: bool
# Customer_CN90378: bool
# Customer_CN91738: bool
# Customer_CO12132: bool
# Customer_CO15448: bool
# Customer_CO16841: bool
# Customer_CO19402: bool
# Customer_CO23919: bool
# Customer_CO25601: bool
# Customer_CO44221: bool
# Customer_CO44659: bool
# Customer_CO53249: bool
# Customer_CO53758: bool
# Customer_CO56168: bool
# Customer_CO68055: bool
# Customer_CO71128: bool
# Customer_CO71312: bool
# Customer_CO75086: bool
# Customer_CO91673: bool
# Customer_CP19929: bool
# Customer_CP27565: bool
# Customer_CP28581: bool
# Customer_CP30637: bool
# Customer_CP32818: bool
# Customer_CP38401: bool
# Customer_CP47989: bool
# Customer_CP66511: bool
# Customer_CP67787: bool
# Customer_CP74755: bool
# Customer_CP76842: bool
# Customer_CP85232: bool
# Customer_CP87192: bool
# Customer_CP93345: bool
# Customer_CP98451: bool
# Customer_CP99334: bool
# Customer_CQ15251: bool
# Customer_CQ19667: bool
# Customer_CQ21583: bool
# Customer_CQ57225: bool
# Customer_CQ59706: bool
# Customer_CQ72935: bool
# Customer_CQ75652: bool
# Customer_CQ76030: bool
# Customer_CQ76876: bool
# Customer_CQ78705: bool
# Customer_CQ80529: bool
# Customer_CQ81839: bool
# Customer_CR12479: bool
# Customer_CR20811: bool
# Customer_CR33417: bool
# Customer_CR37971: bool
# Customer_CR40615: bool
# Customer_CR41258: bool
# Customer_CR48975: bool
# Customer_CR56473: bool
# Customer_CR57148: bool
# Customer_CR59224: bool
# Customer_CR76145: bool
# Customer_CR85257: bool
# Customer_CR86548: bool
# Customer_CR88883: bool
# Customer_CR92272: bool
# Customer_CR92802: bool
# Customer_CR99369: bool
# Customer_CS26667: bool
# Customer_CS29328: bool
# Customer_CS30372: bool
# Customer_CS30775: bool
# Customer_CS32416: bool
# Customer_CS35098: bool
# Customer_CS51928: bool
# Customer_CS55808: bool
# Customer_CS70768: bool
# Customer_CS84396: bool
# Customer_CS93971: bool
# Customer_CT11176: bool
# Customer_CT18212: bool
# Customer_CT41158: bool
# Customer_CT47738: bool
# Customer_CT50487: bool
# Customer_CT51200: bool
# Customer_CT53265: bool
# Customer_CT62892: bool
# Customer_CT84535: bool
# Customer_CT86614: bool
# Customer_CT88432: bool
# Customer_CT96082: bool
# Customer_CU10179: bool
# Customer_CU13711: bool
# Customer_CU19735: bool
# Customer_CU26127: bool
# Customer_CU36986: bool
# Customer_CU69816: bool
# Customer_CU84967: bool
# Customer_CV13878: bool
# Customer_CV24005: bool
# Customer_CV29889: bool
# Customer_CV31235: bool
# Customer_CV35709: bool
# Customer_CV40610: bool
# Customer_CV44550: bool
# Customer_CV48634: bool
# Customer_CV49750: bool
# Customer_CV57391: bool
# Customer_CV63337: bool
# Customer_CV64725: bool
# Customer_CV70978: bool
# Customer_CV72453: bool
# Customer_CV75841: bool
# Customer_CV78865: bool
# Customer_CV86445: bool
# Customer_CV90092: bool
# Customer_CV95479: bool
# Customer_CW12066: bool
# Customer_CW13886: bool
# Customer_CW15758: bool
# Customer_CW16221: bool
# Customer_CW27031: bool
# Customer_CW35098: bool
# Customer_CW38361: bool
# Customer_CW49887: bool
# Customer_CW57351: bool
# Customer_CW57656: bool
# Customer_CW63533: bool
# Customer_CW77053: bool
# Customer_CW80905: bool
# Customer_CW82151: bool
# Customer_CW85845: bool
# Customer_CW92156: bool
# Customer_CW98743: bool
# Customer_CW98845: bool
# Customer_CX12134: bool
# Customer_CX20455: bool
# Customer_CX22458: bool
# Customer_CX34236: bool
# Customer_CX58204: bool
# Customer_CX85598: bool
# Customer_CX99919: bool
# Customer_CY12922: bool
# Customer_CY18875: bool
# Customer_CY30418: bool
# Customer_CY33307: bool
# Customer_CY45848: bool
# Customer_CY47265: bool
# Customer_CY49953: bool
# Customer_CY50337: bool
# Customer_CY59740: bool
# Customer_CY80935: bool
# Customer_CY90231: bool
# Customer_CY97519: bool
# Customer_CZ19025: bool
# Customer_CZ20440: bool
# Customer_CZ25193: bool
# Customer_CZ33664: bool
# Customer_CZ35936: bool
# Customer_CZ56843: bool
# Customer_CZ62883: bool
# Customer_CZ72326: bool
# Customer_CZ84042: bool
# Customer_CZ96653: bool
# Customer_DA10870: bool
# Customer_DA20472: bool
# Customer_DA20791: bool
# Customer_DA26490: bool
# Customer_DA28072: bool
# Customer_DA34555: bool
# Customer_DA35744: bool
# Customer_DA40009: bool
# Customer_DA54619: bool
# Customer_DA57177: bool
# Customer_DA69469: bool
# Customer_DA73502: bool
# Customer_DA74095: bool
# Customer_DA79098: bool
# Customer_DA79544: bool
# Customer_DA84476: bool
# Customer_DA99797: bool
# Customer_DB16336: bool
# Customer_DB17162: bool
# Customer_DB26077: bool
# Customer_DB28487: bool
# Customer_DB28979: bool
# Customer_DB34757: bool
# Customer_DB42794: bool
# Customer_DB50188: bool
# Customer_DB71122: bool
# Customer_DB75522: bool
# Customer_DB79306: bool
# Customer_DB79694: bool
# Customer_DB91647: bool
# Customer_DB93245: bool
# Customer_DC31768: bool
# Customer_DC37886: bool
# Customer_DC46685: bool
# Customer_DC46965: bool
# Customer_DC62428: bool
# Customer_DC70690: bool
# Customer_DC78147: bool
# Customer_DC79319: bool
# Customer_DC83427: bool
# Customer_DC91024: bool
# Customer_DD22139: bool
# Customer_DD27563: bool
# Customer_DD27635: bool
# Customer_DD28380: bool
# Customer_DD44177: bool
# Customer_DD68171: bool
# Customer_DD88614: bool
# Customer_DD94148: bool
# Customer_DD97473: bool
# Customer_DE18949: bool
# Customer_DE21533: bool
# Customer_DE21910: bool
# Customer_DE23903: bool
# Customer_DE28132: bool
# Customer_DE34457: bool
# Customer_DE37110: bool
# Customer_DE53644: bool
# Customer_DE55857: bool
# Customer_DE59454: bool
# Customer_DE71115: bool
# Customer_DE75225: bool
# Customer_DE78840: bool
# Customer_DE91458: bool
# Customer_DF21541: bool
# Customer_DF40318: bool
# Customer_DF49110: bool
# Customer_DF62718: bool
# Customer_DF65548: bool
# Customer_DF66914: bool
# Customer_DF71709: bool
# Customer_DF74270: bool
# Customer_DF86803: bool
# Customer_DF94525: bool
# Customer_DF95759: bool
# Customer_DF97701: bool
# Customer_DG21323: bool
# Customer_DG23204: bool
# Customer_DG30586: bool
# Customer_DG31826: bool
# Customer_DG33206: bool
# Customer_DG34434: bool
# Customer_DG46291: bool
# Customer_DG51590: bool
# Customer_DG68667: bool
# Customer_DG80424: bool
# Customer_DG90902: bool
# Customer_DH13219: bool
# Customer_DH14632: bool
# Customer_DH18269: bool
# Customer_DH25145: bool
# Customer_DH41343: bool
# Customer_DH51686: bool
# Customer_DH61947: bool
# Customer_DH68234: bool
# Customer_DH68319: bool
# Customer_DH85144: bool
# Customer_DH93217: bool
# Customer_DH93540: bool
# Customer_DH95491: bool
# Customer_DH99299: bool
# Customer_DI19952: bool
# Customer_DI22093: bool
# Customer_DI30528: bool
# Customer_DI42246: bool
# Customer_DI45039: bool
# Customer_DI51103: bool
# Customer_DI65961: bool
# Customer_DI82448: bool
# Customer_DI89983: bool
# Customer_DJ11965: bool
# Customer_DJ22229: bool
# Customer_DJ27518: bool
# Customer_DJ34695: bool
# Customer_DJ42087: bool
# Customer_DJ47372: bool
# Customer_DJ51510: bool
# Customer_DJ52170: bool
# Customer_DJ71217: bool
# Customer_DJ77787: bool
# Customer_DJ87316: bool
# Customer_DJ93289: bool
# Customer_DK19711: bool
# Customer_DK20428: bool
# Customer_DK26322: bool
# Customer_DK32872: bool
# Customer_DK41858: bool
# Customer_DK49336: bool
# Customer_DK66277: bool
# Customer_DK69871: bool
# Customer_DK81475: bool
# Customer_DK92014: bool
# Customer_DK93464: bool
# Customer_DK94262: bool
# Customer_DK98861: bool
# Customer_DL11519: bool
# Customer_DL14445: bool
# Customer_DL17162: bool
# Customer_DL20327: bool
# Customer_DL26809: bool
# Customer_DL34364: bool
# Customer_DL36983: bool
# Customer_DL45122: bool
# Customer_DL53457: bool
# Customer_DL55489: bool
# Customer_DM16101: bool
# Customer_DM22923: bool
# Customer_DM34321: bool
# Customer_DM42912: bool
# Customer_DM59629: bool
# Customer_DM59806: bool
# Customer_DM74502: bool
# Customer_DM76654: bool
# Customer_DM77491: bool
# Customer_DM79012: bool
# Customer_DM95829: bool
# Customer_DN10177: bool
# Customer_DN14211: bool
# Customer_DN21342: bool
# Customer_DN29808: bool
# Customer_DN30013: bool
# Customer_DN34058: bool
# Customer_DN46994: bool
# Customer_DN66715: bool
# Customer_DN67273: bool
# Customer_DN71979: bool
# Customer_DN76322: bool
# Customer_DN77617: bool
# Customer_DN92191: bool
# Customer_DN98431: bool
# Customer_DO12179: bool
# Customer_DO18118: bool
# Customer_DO20853: bool
# Customer_DO41287: bool
# Customer_DO48071: bool
# Customer_DO51363: bool
# Customer_DO60145: bool
# Customer_DO70918: bool
# Customer_DO80363: bool
# Customer_DO83038: bool
# Customer_DO83789: bool
# Customer_DO93657: bool
# Customer_DO95670: bool
# Customer_DO98345: bool
# Customer_DP13082: bool
# Customer_DP19210: bool
# Customer_DP23630: bool
# Customer_DP26592: bool
# Customer_DP33625: bool
# Customer_DP39365: bool
# Customer_DP45816: bool
# Customer_DP46882: bool
# Customer_DP50640: bool
# Customer_DP50922: bool
# Customer_DP57381: bool
# Customer_DP63956: bool
# Customer_DP77737: bool
# Customer_DP84567: bool
# Customer_DP87594: bool
# Customer_DP92488: bool
# Customer_DP97298: bool
# Customer_DQ10761: bool
# Customer_DQ15807: bool
# Customer_DQ19343: bool
# Customer_DQ19344: bool
# Customer_DQ28641: bool
# Customer_DQ31994: bool
# Customer_DQ34772: bool
# Customer_DQ35195: bool
# Customer_DQ45854: bool
# Customer_DQ50258: bool
# Customer_DQ50538: bool
# Customer_DQ54144: bool
# Customer_DQ55516: bool
# Customer_DQ58142: bool
# Customer_DQ69331: bool
# Customer_DQ71306: bool
# Customer_DQ79499: bool
# Customer_DQ92905: bool
# Customer_DQ93036: bool
# Customer_DQ98402: bool
# Customer_DR27120: bool
# Customer_DR38127: bool
# Customer_DR54244: bool
# Customer_DR68556: bool
# Customer_DR77208: bool
# Customer_DR77989: bool
# Customer_DR84620: bool
# Customer_DR84843: bool
# Customer_DR88293: bool
# Customer_DR93103: bool
# Customer_DS31990: bool
# Customer_DS32060: bool
# Customer_DS34823: bool
# Customer_DS45802: bool
# Customer_DS45844: bool
# Customer_DS46955: bool
# Customer_DS47984: bool
# Customer_DS50601: bool
# Customer_DS57918: bool
# Customer_DS58268: bool
# Customer_DS62172: bool
# Customer_DS75515: bool
# Customer_DS81757: bool
# Customer_DS97676: bool
# Customer_DT35588: bool
# Customer_DT52189: bool
# Customer_DT53270: bool
# Customer_DT59560: bool
# Customer_DT82702: bool
# Customer_DT85712: bool
# Customer_DT99586: bool
# Customer_DU18362: bool
# Customer_DU38713: bool
# Customer_DU39756: bool
# Customer_DU60004: bool
# Customer_DU66620: bool
# Customer_DU66880: bool
# Customer_DU68331: bool
# Customer_DV22542: bool
# Customer_DV24592: bool
# Customer_DV27428: bool
# Customer_DV38369: bool
# Customer_DV51398: bool
# Customer_DV57698: bool
# Customer_DV58197: bool
# Customer_DV62119: bool
# Customer_DV85764: bool
# Customer_DW14769: bool
# Customer_DW19309: bool
# Customer_DW20514: bool
# Customer_DW29763: bool
# Customer_DW37404: bool
# Customer_DW59142: bool
# Customer_DW62043: bool
# Customer_DW62397: bool
# Customer_DW71192: bool
# Customer_DW72437: bool
# Customer_DW86238: bool
# Customer_DW88734: bool
# Customer_DW96592: bool
# Customer_DX28320: bool
# Customer_DX31066: bool
# Customer_DX34647: bool
# Customer_DX70966: bool
# Customer_DX80961: bool
# Customer_DX91392: bool
# Customer_DX91931: bool
# Customer_DX98298: bool
# Customer_DY17416: bool
# Customer_DY18947: bool
# Customer_DY22043: bool
# Customer_DY22077: bool
# Customer_DY27031: bool
# Customer_DY27653: bool
# Customer_DY30071: bool
# Customer_DY34638: bool
# Customer_DY34902: bool
# Customer_DY35486: bool
# Customer_DY35560: bool
# Customer_DY38083: bool
# Customer_DY49235: bool
# Customer_DY57308: bool
# Customer_DY69629: bool
# Customer_DY73849: bool
# Customer_DY81347: bool
# Customer_DY87071: bool
# Customer_DY87989: bool
# Customer_DY92795: bool
# Customer_DZ35379: bool
# Customer_DZ38951: bool
# Customer_DZ45471: bool
# Customer_DZ48278: bool
# Customer_DZ62350: bool
# Customer_DZ64604: bool
# Customer_DZ85842: bool
# Customer_DZ87709: bool
# Customer_DZ89536: bool
# Customer_EA14700: bool
# Customer_EA23961: bool
# Customer_EA25683: bool
# Customer_EA27048: bool
# Customer_EA52579: bool
# Customer_EA54906: bool
# Customer_EA55071: bool
# Customer_EA61783: bool
# Customer_EA63660: bool
# Customer_EA68909: bool
# Customer_EA87824: bool
# Customer_EB12732: bool
# Customer_EB30823: bool
# Customer_EB34435: bool
# Customer_EB52195: bool
# Customer_EB55390: bool
# Customer_EB59129: bool
# Customer_EB61889: bool
# Customer_EB66698: bool
# Customer_EB72052: bool
# Customer_EB72669: bool
# Customer_EB86696: bool
# Customer_EB93628: bool
# Customer_EC13382: bool
# Customer_EC18611: bool
# Customer_EC22495: bool
# Customer_EC28314: bool
# Customer_EC28398: bool
# Customer_EC44438: bool
# Customer_EC51047: bool
# Customer_EC66666: bool
# Customer_EC71857: bool
# Customer_EC71986: bool
# Customer_EC78254: bool
# Customer_EC94366: bool
# Customer_ED13353: bool
# Customer_ED28429: bool
# Customer_ED29955: bool
# Customer_ED44765: bool
# Customer_ED50963: bool
# Customer_ED61615: bool
# Customer_ED65109: bool
# Customer_ED80746: bool
# Customer_ED82243: bool
# Customer_ED87136: bool
# Customer_ED89934: bool
# Customer_ED90879: bool
# Customer_ED91989: bool
# Customer_EE24901: bool
# Customer_EE28119: bool
# Customer_EE34821: bool
# Customer_EE48429: bool
# Customer_EE49066: bool
# Customer_EE53627: bool
# Customer_EE57466: bool
# Customer_EE59791: bool
# Customer_EE76374: bool
# Customer_EE95568: bool
# Customer_EE96187: bool
# Customer_EE98024: bool
# Customer_EE99484: bool
# Customer_EF13716: bool
# Customer_EF21564: bool
# Customer_EF41225: bool
# Customer_EF52334: bool
# Customer_EF52978: bool
# Customer_EF84269: bool
# Customer_EF87528: bool
# Customer_EF99768: bool
# Customer_EG10175: bool
# Customer_EG12987: bool
# Customer_EG16813: bool
# Customer_EG21289: bool
# Customer_EG36536: bool
# Customer_EG40670: bool
# Customer_EG40823: bool
# Customer_EG48956: bool
# Customer_EG54606: bool
# Customer_EG56026: bool
# Customer_EG62398: bool
# Customer_EG81847: bool
# Customer_EG94326: bool
# Customer_EG94409: bool
# Customer_EG97649: bool
# Customer_EH13261: bool
# Customer_EH16250: bool
# Customer_EH22538: bool
# Customer_EH27304: bool
# Customer_EH37385: bool
# Customer_EH41854: bool
# Customer_EH51056: bool
# Customer_EH69733: bool
# Customer_EH70612: bool
# Customer_EH86912: bool
# Customer_EI10204: bool
# Customer_EI17022: bool
# Customer_EI17753: bool
# Customer_EI29901: bool
# Customer_EI32190: bool
# Customer_EI45850: bool
# Customer_EI46264: bool
# Customer_EI57866: bool
# Customer_EI58541: bool
# Customer_EI58852: bool
# Customer_EI71732: bool
# Customer_EI85244: bool
# Customer_EI85578: bool
# Customer_EI89831: bool
# Customer_EI91403: bool
# Customer_EJ19449: bool
# Customer_EJ43595: bool
# Customer_EJ44139: bool
# Customer_EJ67407: bool
# Customer_EJ73184: bool
# Customer_EJ77557: bool
# Customer_EJ77678: bool
# Customer_EJ86526: bool
# Customer_EJ90880: bool
# Customer_EJ95100: bool
# Customer_EJ96266: bool
# Customer_EJ97834: bool
# Customer_EK13316: bool
# Customer_EK19337: bool
# Customer_EK40672: bool
# Customer_EK50729: bool
# Customer_EK56325: bool
# Customer_EK58626: bool
# Customer_EK59571: bool
# Customer_EK61334: bool
# Customer_EK71077: bool
# Customer_EK87467: bool
# Customer_EK87864: bool
# Customer_EK91340: bool
# Customer_EK95340: bool
# Customer_EL11108: bool
# Customer_EL41362: bool
# Customer_EL42453: bool
# Customer_EL44544: bool
# Customer_EL55611: bool
# Customer_EL61402: bool
# Customer_EL62967: bool
# Customer_EL67979: bool
# Customer_EL70257: bool
# Customer_EL77795: bool
# Customer_EL81968: bool
# Customer_EL82767: bool
# Customer_EL88957: bool
# Customer_EL89222: bool
# Customer_EL92515: bool
# Customer_EL93539: bool
# Customer_EL99335: bool
# Customer_EM16179: bool
# Customer_EM27919: bool
# Customer_EM29019: bool
# Customer_EM29359: bool
# Customer_EM32982: bool
# Customer_EM39400: bool
# Customer_EM43724: bool
# Customer_EM53324: bool
# Customer_EM66435: bool
# Customer_EM77767: bool
# Customer_EM78211: bool
# Customer_EM85557: bool
# Customer_EM89554: bool
# Customer_EN21086: bool
# Customer_EN27946: bool
# Customer_EN31802: bool
# Customer_EN32990: bool
# Customer_EN38348: bool
# Customer_EN54716: bool
# Customer_EN60878: bool
# Customer_EN61670: bool
# Customer_EN65835: bool
# Customer_EN72010: bool
# Customer_EN77569: bool
# Customer_EN89709: bool
# Customer_EN97874: bool
# Customer_EO17010: bool
# Customer_EO24423: bool
# Customer_EO38569: bool
# Customer_EO40136: bool
# Customer_EO42272: bool
# Customer_EO51920: bool
# Customer_EO56466: bool
# Customer_EO74797: bool
# Customer_EO75698: bool
# Customer_EO77382: bool
# Customer_EO87464: bool
# Customer_EO91797: bool
# Customer_EO95166: bool
# Customer_EO95328: bool
# Customer_EO95783: bool
# Customer_EO99750: bool
# Customer_EP10645: bool
# Customer_EP18940: bool
# Customer_EP26605: bool
# Customer_EP29567: bool
# Customer_EP34249: bool
# Customer_EP35930: bool
# Customer_EP46328: bool
# Customer_EP48362: bool
# Customer_EP61084: bool
# Customer_EP61197: bool
# Customer_EP64069: bool
# Customer_EP64833: bool
# Customer_EP80820: bool
# Customer_EP82214: bool
# Customer_EP83939: bool
# Customer_EP93369: bool
# Customer_EQ15944: bool
# Customer_EQ59908: bool
# Customer_EQ62488: bool
# Customer_EQ68292: bool
# Customer_EQ69638: bool
# Customer_EQ75249: bool
# Customer_EQ82942: bool
# Customer_EQ87425: bool
# Customer_EQ90867: bool
# Customer_EQ96084: bool
# Customer_ER10834: bool
# Customer_ER19995: bool
# Customer_ER20865: bool
# Customer_ER29107: bool
# Customer_ER40041: bool
# Customer_ER49844: bool
# Customer_ER50891: bool
# Customer_ER51965: bool
# Customer_ER52041: bool
# Customer_ER63193: bool
# Customer_ER65086: bool
# Customer_ER66372: bool
# Customer_ER97256: bool
# Customer_ES16126: bool
# Customer_ES21306: bool
# Customer_ES34753: bool
# Customer_ES39217: bool
# Customer_ES57969: bool
# Customer_ES66762: bool
# Customer_ES82658: bool
# Customer_ES87355: bool
# Customer_ES88339: bool
# Customer_ES90681: bool
# Customer_ES93923: bool
# Customer_ES97399: bool
# Customer_ET10831: bool
# Customer_ET22260: bool
# Customer_ET39822: bool
# Customer_ET44462: bool
# Customer_ET45138: bool
# Customer_ET47892: bool
# Customer_ET64028: bool
# Customer_ET64307: bool
# Customer_ET79528: bool
# Customer_ET80689: bool
# Customer_ET81343: bool
# Customer_ET87938: bool
# Customer_ET88948: bool
# Customer_ET89070: bool
# Customer_ET90029: bool
# Customer_EU19773: bool
# Customer_EU21305: bool
# Customer_EU38033: bool
# Customer_EU48798: bool
# Customer_EU54076: bool
# Customer_EU59853: bool
# Customer_EU68825: bool
# Customer_EU78163: bool
# Customer_EU81458: bool
# Customer_EU95973: bool
# Customer_EU98982: bool
# Customer_EV14053: bool
# Customer_EV14479: bool
# Customer_EV15014: bool
# Customer_EV15646: bool
# Customer_EV19512: bool
# Customer_EV32492: bool
# Customer_EV34073: bool
# Customer_EV39201: bool
# Customer_EV39637: bool
# Customer_EV46476: bool
# Customer_EV53200: bool
# Customer_EV57176: bool
# Customer_EV66951: bool
# Customer_EV68375: bool
# Customer_EV68966: bool
# Customer_EV78251: bool
# Customer_EV95033: bool
# Customer_EW13798: bool
# Customer_EW15755: bool
# Customer_EW16697: bool
# Customer_EW17514: bool
# Customer_EW27959: bool
# Customer_EW33419: bool
# Customer_EW34576: bool
# Customer_EW34780: bool
# Customer_EW35231: bool
# Customer_EW38459: bool
# Customer_EW46828: bool
# Customer_EW51866: bool
# Customer_EW67766: bool
# Customer_EW68125: bool
# Customer_EW73206: bool
# Customer_EW73451: bool
# Customer_EW82164: bool
# Customer_EW86465: bool
# Customer_EX13440: bool
# Customer_EX46492: bool
# Customer_EX61844: bool
# Customer_EX63393: bool
# Customer_EX72956: bool
# Customer_EX73249: bool
# Customer_EX80215: bool
# Customer_EX89625: bool
# Customer_EX97404: bool
# Customer_EY19523: bool
# Customer_EY27917: bool
# Customer_EY49684: bool
# Customer_EY50028: bool
# Customer_EY71418: bool
# Customer_EY71439: bool
# Customer_EY74093: bool
# Customer_EY75197: bool
# Customer_EY78874: bool
# Customer_EY83434: bool
# Customer_EY86980: bool
# Customer_EY89842: bool
# Customer_EY97047: bool
# Customer_EZ11341: bool
# Customer_EZ20115: bool
# Customer_EZ30498: bool
# Customer_EZ39383: bool
# Customer_EZ41764: bool
# Customer_EZ43738: bool
# Customer_EZ48093: bool
# Customer_EZ48947: bool
# Customer_EZ50606: bool
# Customer_EZ51276: bool
# Customer_EZ60033: bool
# Customer_EZ70589: bool
# Customer_EZ70847: bool
# Customer_EZ71780: bool
# Customer_EZ74530: bool
# Customer_EZ75048: bool
# Customer_EZ77297: bool
# Customer_EZ78112: bool
# Customer_EZ80325: bool
# Customer_EZ85603: bool
# Customer_FA15338: bool
# Customer_FA15811: bool
# Customer_FA39525: bool
# Customer_FA46418: bool
# Customer_FA57012: bool
# Customer_FA59186: bool
# Customer_FA82777: bool
# Customer_FA89548: bool
# Customer_FA90076: bool
# Customer_FA90739: bool
# Customer_FB17016: bool
# Customer_FB21121: bool
# Customer_FB23788: bool
# Customer_FB25242: bool
# Customer_FB49203: bool
# Customer_FB55024: bool
# Customer_FB68802: bool
# Customer_FB71914: bool
# Customer_FB76635: bool
# Customer_FB77856: bool
# Customer_FB80807: bool
# Customer_FB84235: bool
# Customer_FB84409: bool
# Customer_FB95495: bool
# Customer_FC10193: bool
# Customer_FC15606: bool
# Customer_FC46260: bool
# Customer_FC48492: bool
# Customer_FC52000: bool
# Customer_FC59209: bool
# Customer_FC68244: bool
# Customer_FC70869: bool
# Customer_FD11364: bool
# Customer_FD14790: bool
# Customer_FD16853: bool
# Customer_FD20455: bool
# Customer_FD21881: bool
# Customer_FD34314: bool
# Customer_FD36230: bool
# Customer_FD45309: bool
# Customer_FD55376: bool
# Customer_FD64348: bool
# Customer_FD72269: bool
# Customer_FD75102: bool
# Customer_FD79560: bool
# Customer_FD98839: bool
# Customer_FE12805: bool
# Customer_FE20514: bool
# Customer_FE24232: bool
# Customer_FE46445: bool
# Customer_FE62142: bool
# Customer_FE67098: bool
# Customer_FE70473: bool
# Customer_FE73696: bool
# Customer_FE82005: bool
# Customer_FE84109: bool
# Customer_FE84989: bool
# Customer_FE90301: bool
# Customer_FE93665: bool
# Customer_FE93959: bool
# Customer_FF28650: bool
# Customer_FF31523: bool
# Customer_FF38892: bool
# Customer_FF53048: bool
# Customer_FF58467: bool
# Customer_FF61670: bool
# Customer_FF65294: bool
# Customer_FF68864: bool
# Customer_FF75737: bool
# Customer_FF77476: bool
# Customer_FF84784: bool
# Customer_FF93355: bool
# Customer_FF94034: bool
# Customer_FF94341: bool
# Customer_FG15154: bool
# Customer_FG15434: bool
# Customer_FG16766: bool
# Customer_FG16885: bool
# Customer_FG18525: bool
# Customer_FG21322: bool
# Customer_FG21377: bool
# Customer_FG23952: bool
# Customer_FG24548: bool
# Customer_FG24850: bool
# Customer_FG31425: bool
# Customer_FG35165: bool
# Customer_FG43850: bool
# Customer_FG46258: bool
# Customer_FG46631: bool
# Customer_FG47217: bool
# Customer_FG60807: bool
# Customer_FG63582: bool
# Customer_FG63647: bool
# Customer_FG64765: bool
# Customer_FG69718: bool
# Customer_FG71665: bool
# Customer_FG77231: bool
# Customer_FG91922: bool
# Customer_FG96614: bool
# Customer_FG99706: bool
# Customer_FH14955: bool
# Customer_FH22095: bool
# Customer_FH22442: bool
# Customer_FH36069: bool
# Customer_FH39423: bool
# Customer_FH39427: bool
# Customer_FH43628: bool
# Customer_FH51383: bool
# Customer_FH61723: bool
# Customer_FH65253: bool
# Customer_FH68849: bool
# Customer_FH69597: bool
# Customer_FH81263: bool
# Customer_FH81409: bool
# Customer_FH83537: bool
# Customer_FH85960: bool
# Customer_FH86704: bool
# Customer_FH97700: bool
# Customer_FI14842: bool
# Customer_FI17798: bool
# Customer_FI20423: bool
# Customer_FI22970: bool
# Customer_FI25204: bool
# Customer_FI45719: bool
# Customer_FI61059: bool
# Customer_FI61655: bool
# Customer_FI61723: bool
# Customer_FI65786: bool
# Customer_FI74985: bool
# Customer_FI75266: bool
# Customer_FI77477: bool
# Customer_FI86516: bool
# Customer_FI90697: bool
# Customer_FI92440: bool
# Customer_FI93397: bool
# Customer_FJ12205: bool
# Customer_FJ24418: bool
# Customer_FJ28407: bool
# Customer_FJ31683: bool
# Customer_FJ57446: bool
# Customer_FJ60600: bool
# Customer_FJ62579: bool
# Customer_FJ76376: bool
# Customer_FK10455: bool
# Customer_FK17363: bool
# Customer_FK28721: bool
# Customer_FK37308: bool
# Customer_FK46365: bool
# Customer_FK54851: bool
# Customer_FK75497: bool
# Customer_FK85203: bool
# Customer_FK94501: bool
# Customer_FK97285: bool
# Customer_FL18392: bool
# Customer_FL22732: bool
# Customer_FL30667: bool
# Customer_FL34139: bool
# Customer_FL50532: bool
# Customer_FL50705: bool
# Customer_FL55134: bool
# Customer_FL59259: bool
# Customer_FL67726: bool
# Customer_FL69363: bool
# Customer_FL69981: bool
# Customer_FL74984: bool
# Customer_FL76894: bool
# Customer_FL77069: bool
# Customer_FL82372: bool
# Customer_FL85008: bool
# Customer_FL96333: bool
# Customer_FM10372: bool
# Customer_FM14335: bool
# Customer_FM25704: bool
# Customer_FM31768: bool
# Customer_FM37864: bool
# Customer_FM38725: bool
# Customer_FM46980: bool
# Customer_FM47139: bool
# Customer_FM52759: bool
# Customer_FM54600: bool
# Customer_FM55990: bool
# Customer_FM59265: bool
# Customer_FM61329: bool
# Customer_FM67585: bool
# Customer_FM70419: bool
# Customer_FM83188: bool
# Customer_FN33339: bool
# Customer_FN44127: bool
# Customer_FN50615: bool
# Customer_FN61865: bool
# Customer_FN66189: bool
# Customer_FN66436: bool
# Customer_FN67085: bool
# Customer_FN69743: bool
# Customer_FN77294: bool
# Customer_FN80010: bool
# Customer_FN98595: bool
# Customer_FN99437: bool
# Customer_FO13070: bool
# Customer_FO13691: bool
# Customer_FO33051: bool
# Customer_FO49408: bool
# Customer_FO63400: bool
# Customer_FO74055: bool
# Customer_FO78512: bool
# Customer_FO82261: bool
# Customer_FO83170: bool
# Customer_FO99259: bool
# Customer_FP10040: bool
# Customer_FP11025: bool
# Customer_FP11777: bool
# Customer_FP17993: bool
# Customer_FP20500: bool
# Customer_FP23103: bool
# Customer_FP27229: bool
# Customer_FP31685: bool
# Customer_FP34904: bool
# Customer_FP39090: bool
# Customer_FP45327: bool
# Customer_FP51143: bool
# Customer_FP53421: bool
# Customer_FP59138: bool
# Customer_FP60372: bool
# Customer_FP65563: bool
# Customer_FP66510: bool
# Customer_FP66891: bool
# Customer_FP67637: bool
# Customer_FP67680: bool
# Customer_FP78531: bool
# Customer_FP86246: bool
# Customer_FP93662: bool
# Customer_FP95606: bool
# Customer_FQ22639: bool
# Customer_FQ24781: bool
# Customer_FQ24929: bool
# Customer_FQ33633: bool
# Customer_FQ46354: bool
# Customer_FQ51281: bool
# Customer_FQ66070: bool
# Customer_FQ66351: bool
# Customer_FQ70521: bool
# Customer_FQ79356: bool
# Customer_FQ83162: bool
# Customer_FQ88964: bool
# Customer_FQ89652: bool
# Customer_FQ93665: bool
# Customer_FR12423: bool
# Customer_FR15853: bool
# Customer_FR15942: bool
# Customer_FR17176: bool
# Customer_FR26341: bool
# Customer_FR34560: bool
# Customer_FR46645: bool
# Customer_FR48094: bool
# Customer_FR54989: bool
# Customer_FR55658: bool
# Customer_FR56877: bool
# Customer_FR66336: bool
# Customer_FR81224: bool
# Customer_FR82361: bool
# Customer_FS19862: bool
# Customer_FS29897: bool
# Customer_FS31523: bool
# Customer_FS37417: bool
# Customer_FS42516: bool
# Customer_FS42690: bool
# Customer_FS49381: bool
# Customer_FS55302: bool
# Customer_FS56709: bool
# Customer_FS67103: bool
# Customer_FS67856: bool
# Customer_FS70572: bool
# Customer_FS76657: bool
# Customer_FS81127: bool
# Customer_FS84707: bool
# Customer_FS86064: bool
# Customer_FS97588: bool
# Customer_FT24768: bool
# Customer_FT56968: bool
# Customer_FT61724: bool
# Customer_FT65961: bool
# Customer_FT74388: bool
# Customer_FT79229: bool
# Customer_FT86104: bool
# Customer_FU17577: bool
# Customer_FU43761: bool
# Customer_FU51754: bool
# Customer_FU55433: bool
# Customer_FU63281: bool
# Customer_FU65756: bool
# Customer_FU74983: bool
# Customer_FU77365: bool
# Customer_FU99476: bool
# Customer_FV15346: bool
# Customer_FV19421: bool
# Customer_FV21968: bool
# Customer_FV22585: bool
# Customer_FV33188: bool
# Customer_FV38119: bool
# Customer_FV42881: bool
# Customer_FV54537: bool
# Customer_FV58292: bool
# Customer_FV62588: bool
# Customer_FV63234: bool
# Customer_FV70604: bool
# Customer_FV83989: bool
# Customer_FV94802: bool
# Customer_FW17421: bool
# Customer_FW43809: bool
# Customer_FW44940: bool
# Customer_FW53453: bool
# Customer_FW91032: bool
# Customer_FW92569: bool
# Customer_FX12602: bool
# Customer_FX26050: bool
# Customer_FX30915: bool
# Customer_FX36546: bool
# Customer_FX39582: bool
# Customer_FX55357: bool
# Customer_FX55409: bool
# Customer_FX55923: bool
# Customer_FX57380: bool
# Customer_FX65946: bool
# Customer_FX67699: bool
# Customer_FX72157: bool
# Customer_FX73249: bool
# Customer_FX78218: bool
# Customer_FX78901: bool
# Customer_FX80133: bool
# Customer_FX81675: bool
# Customer_FX95323: bool
# Customer_FY13480: bool
# Customer_FY21364: bool
# Customer_FY24370: bool
# Customer_FY27460: bool
# Customer_FY30870: bool
# Customer_FY31714: bool
# Customer_FY32213: bool
# Customer_FY32647: bool
# Customer_FY40655: bool
# Customer_FY51713: bool
# Customer_FY56083: bool
# Customer_FY62633: bool
# Customer_FY67942: bool
# Customer_FY70464: bool
# Customer_FY73682: bool
# Customer_FY74419: bool
# Customer_FY77803: bool
# Customer_FY82691: bool
# Customer_FY83287: bool
# Customer_FY84962: bool
# Customer_FY86121: bool
# Customer_FY90924: bool
# Customer_FZ13256: bool
# Customer_FZ16327: bool
# Customer_FZ20933: bool
# Customer_FZ24763: bool
# Customer_FZ29605: bool
# Customer_FZ30935: bool
# Customer_FZ45665: bool
# Customer_FZ55002: bool
# Customer_FZ73016: bool
# Customer_FZ79470: bool
# Customer_FZ89300: bool
# Customer_FZ94690: bool
# Customer_GA27295: bool
# Customer_GA46608: bool
# Customer_GA49547: bool
# Customer_GA50461: bool
# Customer_GA63091: bool
# Customer_GA71186: bool
# Customer_GA74551: bool
# Customer_GA79817: bool
# Customer_GA86186: bool
# Customer_GA89827: bool
# Customer_GA93544: bool
# Customer_GA98025: bool
# Customer_GB12561: bool
# Customer_GB20532: bool
# Customer_GB32334: bool
# Customer_GB33195: bool
# Customer_GB35238: bool
# Customer_GB39003: bool
# Customer_GB39602: bool
# Customer_GB43363: bool
# Customer_GB44176: bool
# Customer_GB45753: bool
# Customer_GB47529: bool
# Customer_GB59748: bool
# Customer_GB66110: bool
# Customer_GB70718: bool
# Customer_GB70736: bool
# Customer_GB71156: bool
# Customer_GB75821: bool
# Customer_GB92679: bool
# Customer_GB94407: bool
# Customer_GC15104: bool
# Customer_GC17585: bool
# Customer_GC29421: bool
# Customer_GC34791: bool
# Customer_GC36679: bool
# Customer_GC40999: bool
# Customer_GC42314: bool
# Customer_GC52187: bool
# Customer_GC69429: bool
# Customer_GC81619: bool
# Customer_GC93551: bool
# Customer_GD11927: bool
# Customer_GD17919: bool
# Customer_GD29440: bool
# ...
# Customer_XX94684: bool
# Customer_XY28151: bool
# Customer_XY33610: bool
# Customer_XY36764: bool
# Customer_XY39691: bool
# Customer_XY48850: bool
# Customer_XY52165: bool
# Customer_XY57950: bool
# Customer_XY66810: bool
# Customer_XY78443: bool
# Customer_XY80192: bool
# Customer_XY91562: bool
# Customer_XZ17273: bool
# Customer_XZ23352: bool
# Customer_XZ34917: bool
# Customer_XZ40716: bool
# Customer_XZ45224: bool
# Customer_XZ51937: bool
# Customer_XZ54522: bool
# Customer_XZ58588: bool
# Customer_XZ62430: bool
# Customer_XZ81226: bool
# Customer_XZ83249: bool
# Customer_XZ87318: bool
# Customer_Y167826: bool
# Customer_YA10507: bool
# Customer_YA11342: bool
# Customer_YA12007: bool
# Customer_YA14448: bool
# Customer_YA15471: bool
# Customer_YA17061: bool
# Customer_YA37626: bool
# Customer_YA52900: bool
# Customer_YA70612: bool
# Customer_YA71207: bool
# Customer_YA78391: bool
# Customer_YA80645: bool
# Customer_YA83600: bool
# Customer_YA87855: bool
# Customer_YB14965: bool
# Customer_YB19340: bool
# Customer_YB39959: bool
# Customer_YB42706: bool
# Customer_YB49540: bool
# Customer_YB49933: bool
# Customer_YB58105: bool
# Customer_YB66933: bool
# Customer_YB70005: bool
# Customer_YB79192: bool
# Customer_YB91420: bool
# Customer_YB96664: bool
# Customer_YC11951: bool
# Customer_YC33550: bool
# Customer_YC43143: bool
# Customer_YC45944: bool
# Customer_YC53575: bool
# Customer_YC63458: bool
# Customer_YC67208: bool
# Customer_YC69616: bool
# Customer_YC77374: bool
# Customer_YC80498: bool
# Customer_YC83239: bool
# Customer_YD22081: bool
# Customer_YD27780: bool
# Customer_YD28431: bool
# Customer_YD45065: bool
# Customer_YD45660: bool
# Customer_YD48962: bool
# Customer_YD53564: bool
# Customer_YD58301: bool
# Customer_YD65161: bool
# Customer_YD71702: bool
# Customer_YD74214: bool
# Customer_YD74948: bool
# Customer_YD76280: bool
# Customer_YD80815: bool
# Customer_YD87931: bool
# Customer_YD89516: bool
# Customer_YE12395: bool
# Customer_YE20366: bool
# Customer_YE24562: bool
# Customer_YE27183: bool
# Customer_YE45848: bool
# Customer_YE46109: bool
# Customer_YE64125: bool
# Customer_YE67531: bool
# Customer_YE68736: bool
# Customer_YE70791: bool
# Customer_YE87442: bool
# Customer_YE88490: bool
# Customer_YE97964: bool
# Customer_YF16441: bool
# Customer_YF26585: bool
# Customer_YF30946: bool
# Customer_YF38355: bool
# Customer_YF54705: bool
# Customer_YF67162: bool
# Customer_YF73402: bool
# Customer_YF81002: bool
# Customer_YF87007: bool
# Customer_YG10247: bool
# Customer_YG11074: bool
# Customer_YG20683: bool
# Customer_YG37894: bool
# Customer_YG38576: bool
# Customer_YG40323: bool
# Customer_YG42297: bool
# Customer_YG44474: bool
# Customer_YG46815: bool
# Customer_YG68142: bool
# Customer_YG71375: bool
# Customer_YG85980: bool
# Customer_YG87460: bool
# Customer_YG92601: bool
# Customer_YG98004: bool
# Customer_YH20696: bool
# Customer_YH23384: bool
# Customer_YH24323: bool
# Customer_YH31618: bool
# Customer_YH43527: bool
# Customer_YH43996: bool
# Customer_YH60476: bool
# Customer_YH61661: bool
# Customer_YH81239: bool
# Customer_YH86106: bool
# Customer_YH86390: bool
# Customer_YH92099: bool
# Customer_YH94097: bool
# Customer_YI28422: bool
# Customer_YI68606: bool
# Customer_YI70563: bool
# Customer_YI73667: bool
# Customer_YI79084: bool
# Customer_YI83073: bool
# Customer_YI85251: bool
# Customer_YI89801: bool
# Customer_YI92916: bool
# Customer_YI95434: bool
# Customer_YI95574: bool
# Customer_YJ14330: bool
# Customer_YJ16399: bool
# Customer_YJ24476: bool
# Customer_YJ35850: bool
# Customer_YJ42538: bool
# Customer_YJ43481: bool
# Customer_YJ53102: bool
# Customer_YJ57293: bool
# Customer_YJ59924: bool
# Customer_YJ69332: bool
# Customer_YJ88573: bool
# Customer_YJ99764: bool
# Customer_YK16362: bool
# Customer_YK23193: bool
# Customer_YK26558: bool
# Customer_YK32760: bool
# Customer_YK36937: bool
# Customer_YK60829: bool
# Customer_YK66939: bool
# Customer_YK83904: bool
# Customer_YK88644: bool
# Customer_YK92080: bool
# Customer_YK92213: bool
# Customer_YK93229: bool
# Customer_YL27602: bool
# Customer_YL34043: bool
# Customer_YL65673: bool
# Customer_YL72747: bool
# Customer_YL74732: bool
# Customer_YL74911: bool
# Customer_YL78930: bool
# Customer_YL83902: bool
# Customer_YL86561: bool
# Customer_YL91288: bool
# Customer_YL91587: bool
# Customer_YM18992: bool
# Customer_YM19146: bool
# Customer_YM20358: bool
# Customer_YM24620: bool
# Customer_YM24654: bool
# Customer_YM43461: bool
# Customer_YM44855: bool
# Customer_YM50253: bool
# Customer_YM53951: bool
# Customer_YM57893: bool
# Customer_YM74115: bool
# Customer_YM77369: bool
# Customer_YM79169: bool
# Customer_YM88338: bool
# Customer_YM94448: bool
# Customer_YM98727: bool
# Customer_YM99866: bool
# Customer_YN10988: bool
# Customer_YN15016: bool
# Customer_YN15967: bool
# Customer_YN17362: bool
# Customer_YN19139: bool
# Customer_YN39714: bool
# Customer_YN46118: bool
# Customer_YN61339: bool
# Customer_YN69214: bool
# Customer_YO11701: bool
# Customer_YO14199: bool
# Customer_YO15246: bool
# Customer_YO23637: bool
# Customer_YO29244: bool
# Customer_YO41331: bool
# Customer_YO49328: bool
# Customer_YO58424: bool
# Customer_YO62357: bool
# Customer_YO81676: bool
# Customer_YO81740: bool
# Customer_YP16210: bool
# Customer_YP17198: bool
# Customer_YP19985: bool
# Customer_YP29527: bool
# Customer_YP32443: bool
# Customer_YP37291: bool
# Customer_YP38413: bool
# Customer_YP40334: bool
# Customer_YP41539: bool
# Customer_YP47665: bool
# Customer_YP67379: bool
# Customer_YP71513: bool
# Customer_YP72749: bool
# Customer_YP75411: bool
# Customer_YP79029: bool
# Customer_YP92773: bool
# Customer_YP96182: bool
# Customer_YQ15567: bool
# Customer_YQ16427: bool
# Customer_YQ24856: bool
# Customer_YQ42353: bool
# Customer_YQ42614: bool
# Customer_YQ44187: bool
# Customer_YQ50209: bool
# Customer_YQ53901: bool
# Customer_YQ58965: bool
# Customer_YQ73717: bool
# Customer_YQ74870: bool
# Customer_YQ75801: bool
# Customer_YQ79307: bool
# Customer_YQ95507: bool
# Customer_YQ98322: bool
# Customer_YQ98465: bool
# Customer_YQ99152: bool
# Customer_YR10848: bool
# Customer_YR34119: bool
# Customer_YR34689: bool
# Customer_YR45605: bool
# Customer_YR49519: bool
# Customer_YR63096: bool
# Customer_YR75102: bool
# Customer_YR76491: bool
# Customer_YR84813: bool
# Customer_YR85283: bool
# Customer_YS49138: bool
# Customer_YS71471: bool
# Customer_YS84064: bool
# Customer_YS94121: bool
# Customer_YT25875: bool
# Customer_YT36855: bool
# Customer_YT43943: bool
# Customer_YT46746: bool
# Customer_YT56442: bool
# Customer_YT69858: bool
# Customer_YT74573: bool
# Customer_YT84266: bool
# Customer_YT91759: bool
# Customer_YT92071: bool
# Customer_YU15037: bool
# Customer_YU21725: bool
# Customer_YU23754: bool
# Customer_YU32377: bool
# Customer_YU35148: bool
# Customer_YU35386: bool
# Customer_YU39743: bool
# Customer_YU49449: bool
# Customer_YU55375: bool
# Customer_YU66872: bool
# Customer_YU72540: bool
# Customer_YU72630: bool
# Customer_YU79270: bool
# Customer_YU83697: bool
# Customer_YU86594: bool
# Customer_YU90693: bool
# Customer_YV22553: bool
# Customer_YV23210: bool
# Customer_YV40022: bool
# Customer_YV49293: bool
# Customer_YV55495: bool
# Customer_YV63603: bool
# Customer_YV64727: bool
# Customer_YV67971: bool
# Customer_YV73432: bool
# Customer_YV76240: bool
# Customer_YV82597: bool
# Customer_YV85096: bool
# Customer_YV88022: bool
# Customer_YV93784: bool
# Customer_YV93921: bool
# Customer_YV97407: bool
# Customer_YW11227: bool
# Customer_YW26148: bool
# Customer_YW43854: bool
# Customer_YW47108: bool
# Customer_YW72997: bool
# Customer_YW85018: bool
# Customer_YW88487: bool
# Customer_YW94562: bool
# Customer_YW95322: bool
# Customer_YX15941: bool
# Customer_YX23800: bool
# Customer_YX35990: bool
# Customer_YX36936: bool
# Customer_YX51934: bool
# Customer_YX54093: bool
# Customer_YX67409: bool
# Customer_YX72707: bool
# Customer_YX84828: bool
# Customer_YX90754: bool
# Customer_YX91403: bool
# Customer_YX96463: bool
# Customer_YX99200: bool
# Customer_YY11432: bool
# Customer_YY12812: bool
# Customer_YY16391: bool
# Customer_YY27420: bool
# Customer_YY29772: bool
# Customer_YY46839: bool
# Customer_YY58769: bool
# Customer_YY63521: bool
# Customer_YY71144: bool
# Customer_YY74036: bool
# Customer_YZ19736: bool
# Customer_YZ36062: bool
# Customer_YZ38778: bool
# Customer_YZ56105: bool
# Customer_YZ60434: bool
# Customer_YZ67161: bool
# Customer_YZ77792: bool
# Customer_YZ79232: bool
# Customer_ZA34848: bool
# Customer_ZA37110: bool
# Customer_ZA44520: bool
# Customer_ZA60820: bool
# Customer_ZA64638: bool
# Customer_ZA83961: bool
# Customer_ZB23962: bool
# Customer_ZB32409: bool
# Customer_ZB40259: bool
# Customer_ZB50601: bool
# Customer_ZB54635: bool
# Customer_ZB62469: bool
# Customer_ZB69355: bool
# Customer_ZB71094: bool
# Customer_ZB72138: bool
# Customer_ZB81881: bool
# Customer_ZB82406: bool
# Customer_ZB84321: bool
# Customer_ZB85648: bool
# Customer_ZB87718: bool
# Customer_ZB88708: bool
# Customer_ZC17276: bool
# Customer_ZC17826: bool
# Customer_ZC24631: bool
# Customer_ZC32761: bool
# Customer_ZC61874: bool
# Customer_ZC62609: bool
# Customer_ZC69696: bool
# Customer_ZC75052: bool
# Customer_ZC89812: bool
# Customer_ZC97171: bool
# Customer_ZC97968: bool
# Customer_ZD13262: bool
# Customer_ZD29731: bool
# Customer_ZD40816: bool
# Customer_ZD42550: bool
# Customer_ZD42919: bool
# Customer_ZD44648: bool
# Customer_ZD59913: bool
# Customer_ZD63451: bool
# Customer_ZD65365: bool
# Customer_ZD71862: bool
# Customer_ZD72991: bool
# Customer_ZE17448: bool
# Customer_ZE40223: bool
# Customer_ZE42703: bool
# Customer_ZE49470: bool
# Customer_ZE53116: bool
# Customer_ZE59592: bool
# Customer_ZE59681: bool
# Customer_ZE60021: bool
# Customer_ZE62067: bool
# Customer_ZE71012: bool
# Customer_ZE76673: bool
# Customer_ZE82255: bool
# Customer_ZE85014: bool
# Customer_ZF27999: bool
# Customer_ZF28570: bool
# Customer_ZF40143: bool
# Customer_ZF40671: bool
# Customer_ZF48094: bool
# Customer_ZF54421: bool
# Customer_ZF64287: bool
# Customer_ZF70768: bool
# Customer_ZF73834: bool
# Customer_ZF77631: bool
# Customer_ZF81243: bool
# Customer_ZF82387: bool
# Customer_ZF84449: bool
# Customer_ZF84966: bool
# Customer_ZF95586: bool
# Customer_ZG10765: bool
# Customer_ZG12619: bool
# Customer_ZG16710: bool
# Customer_ZG17326: bool
# Customer_ZG18090: bool
# Customer_ZG19911: bool
# Customer_ZG23976: bool
# Customer_ZG47195: bool
# Customer_ZG48513: bool
# Customer_ZG54759: bool
# Customer_ZG56744: bool
# Customer_ZG59671: bool
# Customer_ZG69918: bool
# Customer_ZG82127: bool
# Customer_ZG82132: bool
# Customer_ZG84862: bool
# Customer_ZG88784: bool
# Customer_ZG90341: bool
# Customer_ZG94155: bool
# Customer_ZG95780: bool
# Customer_ZH17561: bool
# Customer_ZH18791: bool
# Customer_ZH19885: bool
# Customer_ZH28312: bool
# Customer_ZH28728: bool
# Customer_ZH30674: bool
# Customer_ZH35315: bool
# Customer_ZH42145: bool
# Customer_ZH43085: bool
# Customer_ZH55575: bool
# Customer_ZH89968: bool
# Customer_ZH92587: bool
# Customer_ZH93283: bool
# Customer_ZH98656: bool
# Customer_ZI34278: bool
# Customer_ZI47098: bool
# Customer_ZI47663: bool
# Customer_ZI48518: bool
# Customer_ZI51939: bool
# Customer_ZI60303: bool
# Customer_ZI63885: bool
# Customer_ZI72165: bool
# Customer_ZI85739: bool
# Customer_ZI86917: bool
# Customer_ZI95657: bool
# Customer_ZJ15114: bool
# Customer_ZJ18419: bool
# Customer_ZJ22033: bool
# Customer_ZJ22132: bool
# Customer_ZJ26179: bool
# Customer_ZJ27465: bool
# Customer_ZJ29643: bool
# Customer_ZJ65064: bool
# Customer_ZJ71004: bool
# Customer_ZJ73220: bool
# Customer_ZJ77881: bool
# Customer_ZJ86769: bool
# Customer_ZJ90079: bool
# Customer_ZK11389: bool
# Customer_ZK21724: bool
# Customer_ZK25313: bool
# Customer_ZK38095: bool
# Customer_ZK52226: bool
# Customer_ZK54897: bool
# Customer_ZK56389: bool
# Customer_ZK58906: bool
# Customer_ZK60855: bool
# Customer_ZK61113: bool
# Customer_ZK67670: bool
# Customer_ZK71157: bool
# Customer_ZK83518: bool
# Customer_ZK90062: bool
# Customer_ZL17677: bool
# Customer_ZL18631: bool
# Customer_ZL23478: bool
# Customer_ZL29593: bool
# Customer_ZL30083: bool
# Customer_ZL37444: bool
# Customer_ZL45417: bool
# Customer_ZL53118: bool
# Customer_ZL68596: bool
# Customer_ZL73902: bool
# Customer_ZL82075: bool
# Customer_ZM28138: bool
# Customer_ZM31116: bool
# Customer_ZM33786: bool
# Customer_ZM40672: bool
# Customer_ZM42260: bool
# Customer_ZM45168: bool
# Customer_ZM70632: bool
# Customer_ZM75468: bool
# Customer_ZM84839: bool
# Customer_ZM86949: bool
# Customer_ZM92052: bool
# Customer_ZN18884: bool
# Customer_ZN24083: bool
# Customer_ZN27753: bool
# Customer_ZN27809: bool
# Customer_ZN33412: bool
# Customer_ZN34245: bool
# Customer_ZN36983: bool
# Customer_ZN45349: bool
# Customer_ZN47335: bool
# Customer_ZN59196: bool
# Customer_ZN65873: bool
# Customer_ZN71189: bool
# Customer_ZN86559: bool
# Customer_ZN96843: bool
# Customer_ZN98560: bool
# Customer_ZO14864: bool
# Customer_ZO16199: bool
# Customer_ZO20633: bool
# Customer_ZO23305: bool
# Customer_ZO29478: bool
# Customer_ZO30377: bool
# Customer_ZO31878: bool
# Customer_ZO42514: bool
# Customer_ZO43755: bool
# Customer_ZO44848: bool
# Customer_ZO54248: bool
# Customer_ZO83562: bool
# Customer_ZO89996: bool
# Customer_ZP26168: bool
# Customer_ZP27971: bool
# Customer_ZP47993: bool
# Customer_ZP49970: bool
# Customer_ZP64637: bool
# Customer_ZP80265: bool
# Customer_ZP80713: bool
# Customer_ZP86347: bool
# Customer_ZP91150: bool
# Customer_ZQ11381: bool
# Customer_ZQ22116: bool
# Customer_ZQ28996: bool
# Customer_ZQ35017: bool
# Customer_ZQ37164: bool
# Customer_ZQ37702: bool
# Customer_ZQ48144: bool
# Customer_ZQ51896: bool
# Customer_ZQ59828: bool
# Customer_ZQ92997: bool
# Customer_ZQ94281: bool
# Customer_ZQ94561: bool
# Customer_ZQ96022: bool
# Customer_ZR11692: bool
# Customer_ZR20842: bool
# Customer_ZR22245: bool
# Customer_ZR25747: bool
# Customer_ZR32858: bool
# Customer_ZR40902: bool
# Customer_ZR41880: bool
# Customer_ZR56751: bool
# Customer_ZR58728: bool
# Customer_ZR66788: bool
# Customer_ZR68364: bool
# Customer_ZR72236: bool
# Customer_ZR76229: bool
# Customer_ZR77995: bool
# Customer_ZR81759: bool
# Customer_ZR84007: bool
# Customer_ZR86524: bool
# Customer_ZR88383: bool
# Customer_ZS15062: bool
# Customer_ZS22428: bool
# Customer_ZS32263: bool
# Customer_ZS35053: bool
# Customer_ZS35830: bool
# Customer_ZS36394: bool
# Customer_ZS50183: bool
# Customer_ZS66375: bool
# Customer_ZS72533: bool
# Customer_ZS73935: bool
# Customer_ZS88847: bool
# Customer_ZS94723: bool
# Customer_ZS96174: bool
# Customer_ZT18953: bool
# Customer_ZT26848: bool
# Customer_ZT30559: bool
# Customer_ZT31931: bool
# Customer_ZT52415: bool
# Customer_ZT53375: bool
# Customer_ZT58755: bool
# Customer_ZT60177: bool
# Customer_ZT63368: bool
# Customer_ZT72561: bool
# Customer_ZT86224: bool
# Customer_ZT87452: bool
# Customer_ZU18643: bool
# Customer_ZU25563: bool
# Customer_ZU30804: bool
# Customer_ZU35962: bool
# Customer_ZU50513: bool
# Customer_ZU63258: bool
# Customer_ZU69163: bool
# Customer_ZU71467: bool
# Customer_ZU73588: bool
# Customer_ZU74482: bool
# Customer_ZU76536: bool
# Customer_ZU83252: bool
# Customer_ZU88029: bool
# Customer_ZU88113: bool
# Customer_ZU91897: bool
# Customer_ZU93025: bool
# Customer_ZU96776: bool
# Customer_ZV17267: bool
# Customer_ZV32120: bool
# Customer_ZV32968: bool
# Customer_ZV36800: bool
# Customer_ZV42323: bool
# Customer_ZV43350: bool
# Customer_ZV43428: bool
# Customer_ZV55368: bool
# Customer_ZV80216: bool
# Customer_ZV93969: bool
# Customer_ZV96574: bool
# Customer_ZV99487: bool
# Customer_ZW18871: bool
# Customer_ZW19492: bool
# Customer_ZW25874: bool
# Customer_ZW32080: bool
# Customer_ZW33889: bool
# Customer_ZW51071: bool
# Customer_ZW51790: bool
# Customer_ZW71731: bool
# Customer_ZW76597: bool
# Customer_ZW79814: bool
# Customer_ZW84453: bool
# Customer_ZX17330: bool
# Customer_ZX23819: bool
# Customer_ZX29705: bool
# Customer_ZX35838: bool
# Customer_ZX50209: bool
# Customer_ZX56541: bool
# Customer_ZX68434: bool
# Customer_ZX73673: bool
# Customer_ZX80668: bool
# Customer_ZX83542: bool
# Customer_ZX85480: bool
# Customer_ZX86243: bool
# Customer_ZX93551: bool
# Customer_ZY20779: bool
# Customer_ZY26831: bool
# Customer_ZY33234: bool
# Customer_ZY49833: bool
# Customer_ZY57929: bool
# Customer_ZY60545: bool
# Customer_ZY77695: bool
# Customer_ZY78741: bool
# Customer_ZY90118: bool
# Customer_ZY95807: bool
# Customer_ZY99878: bool
# Customer_ZZ20738: bool
# Customer_ZZ22047: bool
# Customer_ZZ22193: bool
# Customer_ZZ22858: bool
# Customer_ZZ31825: bool
# Customer_ZZ35218: bool
# Customer_ZZ41158: bool
# Customer_ZZ42291: bool
# Customer_ZZ44902: bool
# Customer_ZZ49347: bool
# Customer_ZZ54454: bool
# Customer_ZZ62245: bool
# Customer_ZZ68210: bool
# Customer_ZZ69693: bool
# Customer_ZZ77357: bool
# Customer_ZZ83340: bool
# Customer_ZZ89380: bool
# Customer_ZZ91716: bool
# Sales Channel_Agent: bool
# Sales Channel_Branch: bool
# Sales Channel_Call Center: bool
# Sales Channel_Web: bool
# Vehicle Class_Four-Door Car: bool
# Vehicle Class_Luxury Car: bool
# Vehicle Class_Luxury SUV: bool
# Vehicle Class_SUV: bool
# Vehicle Class_Sports Car: bool
# Vehicle Class_Two-Door Car: bool
# day: int32
# week: UInt32
# month: int32
